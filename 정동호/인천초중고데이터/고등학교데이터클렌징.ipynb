# %%
# 학교현황 데이터클렌징
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
f_high = pd.read_excel('./변수/2018.4.1.자+학교현황(게시용).xlsx',sheet_name='고등학교')

# %%
f_high
# Out:
#                 □ 고등학교 현황 Unnamed: 1 Unnamed: 2 Unnamed: 3    Unnamed: 4  \
# 0    ▶ 작성기준일 : 2018-04-01        NaN        NaN        NaN           NaN
# 1                    ②구군별       ③설립별       ①계열별        ④공학          ⑤학교명
# 2                     NaN        NaN        NaN        NaN           NaN
# 3                     NaN        NaN        NaN        NaN           NaN
# 4                     강화군         공립         일반         공학        교동고등학교
# 5                     강화군         공립         일반         공학        서도고등학교
# 6                     강화군         공립         일반          여      강화여자고등학교
# 7                    일반 계        NaN        NaN        NaN             3
# 8                     강화군         공립        자율형          남        강화고등학교
# 9                   자율형 계        NaN        NaN        NaN             1
# 10                    강화군         공립        특성화         공학   강남영상미디어고등학교
# 11                  특성화 계        NaN        NaN        NaN             1
# ...

# %%
f_high.shape
# Out:
# (214, 28)

# %%
# 주소와 관련없는 열 삭제
f_high.columns
# f_high = f_high.drop(f_high.columns[9:],1)
# f_high = f_high.drop(f_high.columns[[2,3,5,7]],1)

# %%
# 주소가 NaN인 행 삭제
f_high= f_high.dropna()

# %%
f_high
# Out:
#     □ 고등학교 현황 Unnamed: 1    Unnamed: 4                             Unnamed: 6  \
# 1        ②구군별       ③설립별          ⑤학교명                                    ⑦주소
# 4         강화군         공립        교동고등학교              강화군 교동면 교동남로 77(대룡리723-7)
# 5         강화군         공립        서도고등학교            강화군 서도면 주문도길 173(주문도리 53번지)
# 6         강화군         공립      강화여자고등학교            강화군 강화읍 송악길58 (강화읍 관청리 987)
# 8         강화군         공립        강화고등학교             강화군 강화읍 고비고개로 20 (국화리 165)
# 10        강화군         공립   강남영상미디어고등학교            강화군 길상면 강화남로 57 (온수리 409-4)
# 13        강화군         사립        덕신고등학교             강화군 강화읍 고비고개로 45 (국화리 243)
# 14        강화군         사립        삼량고등학교            강화군 내가면 강화서로 184 (고천리 1266)
# 16        강화군         사립       산마을고등학교  강화군 양도면 강화남로 1002번길 73-29 (삼흥리 460)
# 20        계양구         공립        서운고등학교            계양구 아나지로 481 (서운동 55-42번지 )
# 21        계양구         공립        안남고등학교          계양구 아나지로 308번길 9 (작전동 392-10)
# ...

# %%
# 열 명 재설정
# f_high.columns=f_high.loc[1]
# f_high=f_high.drop(1,0)
f_high.columns = ["구군별","설립별","학교명","주소","우편번호"]

# %%
f_high
# Out:
#      구군별 설립별           학교명                                     주소   우편번호
# 4    강화군  공립        교동고등학교              강화군 교동면 교동남로 77(대룡리723-7)  23002
# 5    강화군  공립        서도고등학교            강화군 서도면 주문도길 173(주문도리 53번지)  23008
# 6    강화군  공립      강화여자고등학교            강화군 강화읍 송악길58 (강화읍 관청리 987)  23029
# 8    강화군  공립        강화고등학교             강화군 강화읍 고비고개로 20 (국화리 165)  23028
# 10   강화군  공립   강남영상미디어고등학교            강화군 길상면 강화남로 57 (온수리 409-4)  23050
# 13   강화군  사립        덕신고등학교             강화군 강화읍 고비고개로 45 (국화리 243)  23028
# 14   강화군  사립        삼량고등학교            강화군 내가면 강화서로 184 (고천리 1266)  23018
# 16   강화군  사립       산마을고등학교  강화군 양도면 강화남로 1002번길 73-29 (삼흥리 460)    23056
# 20   계양구  공립        서운고등학교            계양구 아나지로 481 (서운동 55-42번지 )  21074
# 21   계양구  공립        안남고등학교          계양구 아나지로 308번길 9 (작전동 392-10)  21122
# 22   계양구  공립      인천효성고등학교            계양구 새벌로 171번길 21 (효성동 13-1)  21096
# 23   계양구  공립        계산고등학교                 계양구 주부토로 588 (계산동 907)  21030
# ...

# %%
# csv 파일로 내보내기
f_high.to_csv("./변수/인천광역시고등학교현황.csv",index=False, encoding='ms949')
