# %%
# 학교현황 데이터클렌징
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
f_mid = pd.read_excel('./변수/2018.4.1.자+학교현황(게시용).xlsx',sheet_name='중학교')

# %%
f_mid.head(20)
# Out:
#                 □ 중학교 현황 Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4  \
# 0   ▶ 작성기준일 : 2018-04-01        NaN        NaN        NaN             NaN
# 1                교육\n지원청        구군별        설립별       공학구분             학교명
# 2                    NaN        NaN        NaN        NaN             NaN
# 3                    NaN        NaN        NaN        NaN             NaN
# 4                     남부         남구         공립          여         관교여자중학교
# 5                     남부         남구         공립          남           관교중학교
# 6                     남부         남구         공립          여        남인천여자중학교
# 7                     남부         남구         공립          남           선인중학교
# 8                     남부         남구         공립          여         선화여자중학교
# 9                     남부         남구         공립          여         용현여자중학교
# 10                    남부         남구         공립          남           용현중학교
# 11                    남부         남구         공립         공학           인주중학교
# ...

# %%
f_mid.shape
# Out:
# (185, 28)

# %%
f_mid
# Out:
#     Unnamed: 1      Unnamed: 4                            Unnamed: 6  \
# 0          NaN             NaN                                   NaN
# 1          구군별             학교명                                    주소
# 2          NaN             NaN                                   NaN
# 3          NaN             NaN                                   NaN
# 4           남구         관교여자중학교                남구 경원대로 691(관교동 512번지)
# 5           남구           관교중학교           남구 경원대로 670번길 19(관교동 482번지)
# 6           남구        남인천여자중학교                   남구 인하로 426(관교동 335)
# 7           남구           선인중학교                남구 석정로 165 (도화동 235번지)
# 8           남구         선화여자중학교                남구 석정로 165(남구 도화동 235)
# 9           남구         용현여자중학교               남구 낙섬동로 28(용현5동 627-38)
# 10          남구           용현중학교            남구 낙섬동로 16(용현5동 627-435번지)
# 11          남구           인주중학교               남구 매소홀로 335(학익동 430-51)
# 12          남구          인천남중학교              남구 수봉로 16-23(숭의동 41-3번지)
# ...

# %%
# 주소와 관련없는 열 삭제
f_mid.columns
# f_mid = f_mid.drop(f_mid.columns[9:],1)
# f_mid = f_mid.drop(f_mid.columns[[0,2,3,5,7]],1)

# %%
# 주소가 NaN인 행 삭제
f_mid = f_mid.dropna()

# %%
f_mid
# Out:
#     Unnamed: 1      Unnamed: 4                            Unnamed: 6  \
# 1          구군별             학교명                                    주소
# 4           남구         관교여자중학교                남구 경원대로 691(관교동 512번지)
# 5           남구           관교중학교           남구 경원대로 670번길 19(관교동 482번지)
# 6           남구        남인천여자중학교                   남구 인하로 426(관교동 335)
# 7           남구           선인중학교                남구 석정로 165 (도화동 235번지)
# 8           남구         선화여자중학교                남구 석정로 165(남구 도화동 235)
# 9           남구         용현여자중학교               남구 낙섬동로 28(용현5동 627-38)
# 10          남구           용현중학교            남구 낙섬동로 16(용현5동 627-435번지)
# 11          남구           인주중학교               남구 매소홀로 335(학익동 430-51)
# 12          남구          인천남중학교              남구 수봉로 16-23(숭의동 41-3번지)
# 13          남구         인화여자중학교                남구 석정로 165 (도화동 235번지)
# 14          남구        제물포여자중학교            남구 인주대로 470번길 20(주안동 1529)
# 16          남구  인하대학교사범대학부속중학교         남구 재넘이길 123번길 29(학익2동 306-30)
# ...

# %%
# 열 명 재설정
# f_mid.columns=f_mid.loc[1]
# f_mid=f_mid.drop(1,0)

# %%
f_mid
# Out:
# 1    구군별             학교명                                    주소   우편번호
# 4     남구         관교여자중학교                남구 경원대로 691(관교동 512번지)  22232
# 5     남구           관교중학교           남구 경원대로 670번길 19(관교동 482번지)  22240
# 6     남구        남인천여자중학교                   남구 인하로 426(관교동 335)  22240
# 7     남구           선인중학교                남구 석정로 165 (도화동 235번지)  22100
# 8     남구         선화여자중학교                남구 석정로 165(남구 도화동 235)  22100
# 9     남구         용현여자중학교               남구 낙섬동로 28(용현5동 627-38)  22189
# 10    남구           용현중학교            남구 낙섬동로 16(용현5동 627-435번지)  22189
# 11    남구           인주중학교               남구 매소홀로 335(학익동 430-51)  22202
# 12    남구          인천남중학교              남구 수봉로 16-23(숭의동 41-3번지)  22163
# 13    남구         인화여자중학교                남구 석정로 165 (도화동 235번지)  22100
# 14    남구        제물포여자중학교            남구 인주대로 470번길 20(주안동 1529)  22228
# 16    남구  인하대학교사범대학부속중학교         남구 재넘이길 123번길 29(학익2동 306-30)  22211
# ...

# %%
# csv 파일로 내보내기
f_mid.to_csv("./변수/인천광역시중학교현황.csv",index=False, encoding='ms949')
